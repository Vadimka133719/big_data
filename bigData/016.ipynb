# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
from sklearn.metrics import r2_score

# %% [markdown]
# ## Количество отрицательных отзывов зависит от среднего количества совершаемых покупок

# %%
np.random.seed(2)
purchases = np.random.normal(3.0,1.0,1000)
negatives = np.random.normal(10.0,1.0,1000) / purchases

# %%
scatter(purchases,negatives)

# %% [markdown]
# ## Переменные для обучения

# %%
x = np.array(purchases)
y = np.array(negatives)

# %% [markdown]
# ## Полином степени 2(парабола)

# %%
p2 = np.poly1d(np.polyfit(x,y,2))
xp = np.linspace(0,7,100)
plt.scatter(x,y)
plt.plot(xp,p2(xp),c='r')
plt.show()

# %%
r2 = r2_score(y,p2(x))
print(r2)
# Out:
# 0.7804892408280977

# %% [markdown]
# ## Полином степени 5

# %%
p5 = np.poly1d(np.polyfit(x,y,5))
xp = np.linspace(0,7,100)
plt.scatter(x,y)
plt.plot(xp,p5(xp),c='r')
plt.show()

# %%
r2 = r2_score(y,p5(x))
print(r2)
# Out:
# 0.9448293121891198

# %% [markdown]
# ## Полином степени 15 (переобучение, overfitting)

# %%
p15 = np.poly1d(np.polyfit(x,y,15))
xp = np.linspace(0,7,100)
plt.scatter(x,y)
plt.plot(xp,p15(xp),c='r')
plt.show()

# %%
r2 = r2_score(y,p15(x))
print(r2)
# Out:
# 0.9670412575711714
